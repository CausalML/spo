# %%
library(tidyverse)

# %%
setwd('/root/notebooks/spo/outputs/sim')

# %%
data <- read.csv("aggregate.csv")

# %%
data
# Out:
#     run algo   seed beta      kappa_target test_reward test_kl_uniform rank
# 1    0  sft     1   0.4520792 0.2          0.5267666   0.2015445       0
# 2    1  espo    2   0.4970881 0.2          0.5478861   0.2008472       0
# 3    3  dpo     4   1.0192680 0.2          0.5157394   0.1983022       0
# 4    4  smsspo  5   0.2359982 0.2          0.5740415   0.2020664       0
# 5    6  pspo    7   0.4886966 0.2          0.5308359   0.1972614       0
# 6    8  sft     9   0.4860266 0.2          0.5616493   0.2012403       0
# 7    9  espo   10   0.4982324 0.2          0.5146728   0.1998516       0
# 8   11  dpo    12   0.8487680 0.2          0.5330797   0.2030603       0
# 9   12  smsspo 13   0.2333282 0.2          0.5805241   0.1998744       0
# 10  14  pspo   15   0.4654293 0.2          0.5428963   0.1995025       0
# 11  16  sft    17   0.5031910 0.2          0.5796206   0.2051393       0
# 12  17  espo   18   0.5359941 0.2          0.5649218   0.1979702       0
# ...

# %%
data %>% group_by(algo) %>% summarise(mean=mean(test_reward),sd=sd(test_reward))
# Out:
#   algo   mean      sd
# 1 dpo    0.5297616 0.01798615
# 2 espo   0.5541204 0.01713265
# 3 pspo   0.5461442 0.01726213
# 4 sft    0.5485020 0.01769187
# 5 smsspo 0.5640365 0.01773598
